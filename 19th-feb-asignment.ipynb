# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:6071be1f-bf4f-483f-8c30-65d8132198f9.png)

# %% [markdown]
# > Flask is a web application framework written in Python

# %% [markdown]
# > `advantages` :
# >- Flask is a very light weight python framework
# >- developement time is verry less
# >- it is very flexible
# >- Flask is very easy to learn
# >- It provides a moduler way to create a backend

# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:5fe08826-040e-4b07-92b4-e6ff67b2392e.png)

# %% [markdown]
# Code :
#
# ![image.png](attachment:82faff74-360b-4b63-b662-74664dfcf723.png)

# %% [markdown]
# Output :
#
# ![image.png](attachment:32352439-160b-491e-96fa-1f5c5192a467.png)

# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:17580f43-a00e-4b02-ac40-d85ba8c14134.png)

# %% [markdown]
# >`App routing` : it's a mechanism that bind the python function to the given URL. It helps HTTP url to corrosponding python function
#
# >We use app routes to bind a corrosponding python function with URL path. It helps developer to define how application should work on different URL paths and requests. it separates application logic into different views or functions, each responsible for handling a specific request.

# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:1f1bd0c2-15fd-4ef7-9191-399d9c9f6a36.png)

# %% [markdown]
# Code :
#
# ![image.png](attachment:2ca5d1d7-887e-4bca-933b-076510212fbe.png)
# <br></br>

# %% [markdown]
# Output on '/' route :
#
# ![image.png](attachment:27adeb9f-ad05-4803-912f-d27b9ae1f43d.png)

# %% [markdown]
# <br></br>
# Output on '/welcome' route :
#
# ![image.png](attachment:84475b1c-df79-4986-b05c-f4c4b43be740.png)

# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:9b84b2d4-a8e7-4284-af11-c427925f103a.png)

# %% [markdown]
# > url_for() is used in Flask for URL Building.
#
# <br></br>

# %% [markdown]
# Code :
#
# ![image.png](attachment:a85e3a3f-dcb0-4d12-a967-4fc8ab50552f.png)
#
# <br></br>

# %% [markdown]
# Output :
#
# ![image.png](attachment:6f89a02a-b3cd-4343-8d8e-f8c13bc59c06.png)

# %% [markdown]
# On above code
#
# When `url_for('index')` is called, it generates the URL for the `index()` view, which is `/`.
#
# When `url_for('welcome_page', username='ankan')` is called, it generates the URL for the `welcome_page()` view with the username parameter set to 'ankan', which is `/welcome/ankan`.
