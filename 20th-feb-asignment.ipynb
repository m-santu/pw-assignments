# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:d8704258-70b9-43e2-ba28-50f03817a6b8.png)

# %% [markdown]
# >`GET` : this HTTP method used when user wants to fetch some data from the server. when get request send then parameter can be shown in the borwser url path.
#
# >`POST` : this HTTP method used when user wants to send some data to the server. this is a secure method to send some data to the server

# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:326d19fb-23f9-4621-b6db-7d6bee3eef7c.png)

# %% [markdown]
# `request` used to retrieve the data submitted by the user as query parameters, form, JSON, or other type of data that is sent to the server in an HTTP request.

# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:ea068566-46a2-486f-b273-2827ba29e005.png)

# %% [markdown]
# suppose when user log in to our web, we need to redirect him/her to a different url.
#
# So `redirect()` used to redirect the user to different url location

# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:5b797a89-0bb5-4bf5-be1d-0adf986efd0c.png)

# %% [markdown]
# >Templates in Flask are HTML files that are used to generate dynamic content for web pages. Those templates are based on Jinja2 engine and store in a folder called 'templates'

# %% [markdown]
# > we use render_template() to render a html template based on the Jinja2 engine that is found in the application's templates folder.

# %% [markdown]
# ---
# <br></br>
# ## ![image.png](attachment:e6c4d784-e343-40c9-91bd-dc62659cf85e.png)

# %% [markdown]
# API Code :
#
#
# ![image.png](attachment:0224e7c4-9151-4398-b52f-45d701f147e1.png)
# <br></br>

# %% [markdown]
# Postman Testing:
#
# ![image.png](attachment:48b76dee-5771-4ba5-a40b-8d72803bccc4.png)

# %% [markdown]
# <br></br>
# Output :
#
# ![image.png](attachment:fcef92eb-6384-488c-b3e5-efebbf7efa71.png)
